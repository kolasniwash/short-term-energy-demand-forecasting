# %%
import pandas as pd

# %%
# !ls -l ./data/raw_data_ES
# Out:
# total 8216
# -rw-r--r--@ 1 ns  staff  276509 29 Aug 14:55 SYSTEM_VERTICAL_LOAD_201301010000-201401010000_ES.xlsx
# -rw-r--r--@ 1 ns  staff  273110 29 Aug 14:54 SYSTEM_VERTICAL_LOAD_201401010000-201501010000_ES.xlsx
# -rw-r--r--@ 1 ns  staff  180613 29 Aug 14:54 SYSTEM_VERTICAL_LOAD_201501010000-201601010000_ES.xlsx
# -rw-r--r--@ 1 ns  staff  473123 18 Aug 20:03 Total Load - Day Ahead _ Actual_2015.csv
# -rw-r--r--@ 1 ns  staff  474463 18 Aug 20:03 Total Load - Day Ahead _ Actual_2016.csv
# -rw-r--r--@ 1 ns  staff  473173 18 Aug 20:03 Total Load - Day Ahead _ Actual_2017.csv
# -rw-r--r--@ 1 ns  staff  473173 18 Aug 20:00 Total Load - Day Ahead _ Actual_2018.csv
# -rw-r--r--@ 1 ns  staff  447309 18 Aug 20:00 Total Load - Day Ahead _ Actual_2019.csv
# -rw-r--r--  1 ns  staff  946953 20 Aug 19:42 load_forecast_2016_2018.csv

# %%
data = pd.read_excel('./data/raw_data_ES/SYSTEM_VERTICAL_LOAD_201501010000-201601010000_ES.xlsx')

# %%
data = data.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], axis=1)

# %%
data.columns = ['time', 'day_ahead_load', 'actual_load']

# %%
data.dropna(axis=0, how='all')
# Out:
#                                            time           day_ahead_load  \
# 0     01.01.2015 00:00 - 01.01.2016 00:00 - CET                      NaN
# 2                                           NaN                       ES
# 3                                 Time Interval  Day-ahead Vertical Load
# 4                                           NaN                     [MW]
# 5                                 00:00 - 01:00                    26118
# 6                                 01:00 - 02:00                    24934
# 7                                 02:00 - 03:00                    23515
# 8                                 03:00 - 04:00                    22642
# 9                                 04:00 - 05:00                    21785
# 10                                05:00 - 06:00                    21441
# 11                                06:00 - 07:00                    21285
# 12                                07:00 - 08:00                    21545
# ...
